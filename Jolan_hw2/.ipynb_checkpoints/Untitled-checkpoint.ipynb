# %% [markdown]
# # Homework 2: from E(E)R model to relational database model
# ### Jolan Wuyts
#
# Using the Recipe from the third lecture I changed this EER model:

# %%
from IPython.display import Image
Image(filename="hw1solution.png")

# %% [markdown]
# To this Database relationship Model:

# %%
Image(filename="hw2.png")

# %% [markdown]
# Firstly, I created the basic entity sets User, Post, Edit, Badge and Tag, with their respective attributes.
#
# Then I added the subclasses first instead of doing them after the relations. I added Question, Answer, Individual, Community, and Admin.
#
# Thirdly, I looked for one to one relationships but couldn't find any.
#
# After that, i modelled all the many to one relationships, not by adding a new table with the attributes of the connected entity sets, but by adding the key and optional relationship attributes to the entity set that was on the One side of the One to Many Relationship. This added keys to the Edit(made_edit_on relationship), Post(created relationship), and Answer(parent_of relationship) tables.
#
# On to the Many to Many relationships. One could say that the made_edit_on relationship is Many-to-many, and it is, but it is also a multivalued relationship with a entity set that is the One side of that relationship. the Edit entity set was clearly made to pull attributes away from the relationship, so all I gathered that this needed was the User_ID and Post_ID to the edit entity set, and that would be enough. A separate table for made_edit_on is not needed, in my opinion.
# Separate tables ARE needed for the received, voted, tagged_with, and commented relationships. The tagged_with relationship is also multivalued, but it is a threeway Many to Many relationship so I also processed that in thist step. I added the relevant keys and the optional relationship attributes to these new tables.
#
# Since we didn't have to model derived attributes I didn't do so.
#
# All done!
